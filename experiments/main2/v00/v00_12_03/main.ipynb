# %%
import gc
import importlib
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import polars as pl
import seaborn as sns
from atmacup_18 import constants

import utils

importlib.reload(utils)
# Out:
# <module 'utils' from '/home/tatsuya/projects/atmacup/atmacup_18/experiments/main2/v00/v00_12_03/utils.py'>

# %%
RANDOM_STATE = 2024 + 1

# %% [markdown]
# ## データ読み込み

# %%
notebook_dir = Path().resolve()
DATA_DIR = notebook_dir.parents[3].joinpath("data")
DATASET_DIR = DATA_DIR.joinpath("atmaCup#18_dataset")
TR_FEATURES_CSV = DATASET_DIR.joinpath("train_features.csv")
TS_FEATURES_CSV = DATASET_DIR.joinpath("test_features.csv")
IMAGES_DIR = DATASET_DIR.joinpath("images")
TRAFFIC_LIGHTS_CSV = DATASET_DIR.joinpath("traffic_lights.csv")

IMAGE_NAMES = ["image_t.png", "image_t-0.5.png", "image_t-1.0.png"]
TRAFFIC_LIGHTS_BBOX_IMAGE_NAME = constants.TRAFFIC_LIGHT_BBOX_IMAGE_NAME
DEPTH_IMAGE_FILE_PREFIX = constants.DEPTH_IMAGE_FILE_PREFIX
DEPTH_IMAGE_NAMES = [
    f"{DEPTH_IMAGE_FILE_PREFIX}{image_name}.npy" for image_name in IMAGE_NAMES
]
OPTICAL_FLOW_IMAGE_NAME = constants.OPTICAL_FLOW_IMAGE_NAME

TR_IMAGE_FEATURE_TYPE2_CSV = DATASET_DIR.joinpath("train_image_features_type2.csv")
TS_IMAGE_FEATURE_TYPE2_CSV = DATASET_DIR.joinpath("test_image_features_type2.csv")

BASE_PRED_DIR = Path("..", "..", "..", "main", "v00", "v00_15_03")
BASE_OOF_PRED_CSV = BASE_PRED_DIR.joinpath("oof_preds.csv")
BASE_SUBMISSION_CSV = BASE_PRED_DIR.joinpath("submission.csv")

# %%
TARGET_COLS = sum([[f"x_{i}", f"y_{i}", f"z_{i}"] for i in range(6)], [])
BASE_PRED_COLS = [f"base_pred_{col}" for col in TARGET_COLS]

# %%
tr_df = utils.read_feature_csv(TR_FEATURES_CSV)
tr_df.head(2)
# Out:
# shape: (2, 33)
# ┌────────────┬───────────┬──────────┬───────────┬───┬──────────┬───────────┬───────────┬───────────┐
# │ ID         ┆ vEgo      ┆ aEgo     ┆ steeringA ┆ … ┆ z_5      ┆ scene_id  ┆ scene_dse ┆ origin_id │
# │ ---        ┆ ---       ┆ ---      ┆ ngleDeg   ┆   ┆ ---      ┆ ---       ┆ c         ┆ x         │
# │ str        ┆ f64       ┆ f64      ┆ ---       ┆   ┆ f64      ┆ str       ┆ ---       ┆ ---       │
# │            ┆           ┆          ┆ f64       ┆   ┆          ┆           ┆ i32       ┆ i64       │
# ╞════════════╪═══════════╪══════════╪═══════════╪═══╪══════════╪═══════════╪═══════════╪═══════════╡
# │ 00066be8e2 ┆ 5.701526  ┆ 1.538456 ┆ -2.165777 ┆ … ┆ 0.485079 ┆ 00066be8e ┆ 320       ┆ 0         │
# │ 0318869c38 ┆           ┆          ┆           ┆   ┆          ┆ 20318869c ┆           ┆           │
# │ c66be46663 ┆           ┆          ┆           ┆   ┆          ┆ 38c66be46 ┆           ┆           │
# │ …          ┆           ┆          ┆           ┆   ┆          ┆ 663…      ┆           ┆           │
# │ 00066be8e2 ┆ 11.176292 ┆ 0.279881 ┆ -11.62569 ┆ … ┆ 0.073083 ┆ 00066be8e ┆ 420       ┆ 1         │
# │ 0318869c38 ┆           ┆          ┆ 7         ┆   ┆          ┆ 20318869c ┆           ┆           │
# │ c66be46663 ┆           ┆          ┆           ┆   ┆          ┆ 38c66be46 ┆           ┆           │
# │ …          ┆           ┆          ┆           ┆   ┆          ┆ 663…      ┆           ┆           │
# └────────────┴───────────┴──────────┴───────────┴───┴──────────┴───────────┴───────────┴───────────┘

# %%
ts_df = utils.read_feature_csv(TS_FEATURES_CSV)
ts_df.head(2)
# Out:
# shape: (2, 15)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ ID        ┆ vEgo     ┆ aEgo      ┆ steeringA ┆ … ┆ rightBlin ┆ scene_id  ┆ scene_dse ┆ origin_id │
# │ ---       ┆ ---      ┆ ---       ┆ ngleDeg   ┆   ┆ ker       ┆ ---       ┆ c         ┆ x         │
# │ str       ┆ f64      ┆ f64       ┆ ---       ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---       │
# │           ┆          ┆           ┆ f64       ┆   ┆ bool      ┆           ┆ i32       ┆ i64       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 012baccc1 ┆ 3.374273 ┆ -0.01936  ┆ -34.00841 ┆ … ┆ false     ┆ 012baccc1 ┆ 120       ┆ 0         │
# │ 45d400c89 ┆          ┆           ┆ 5         ┆   ┆           ┆ 45d400c89 ┆           ┆           │
# │ 6cb82065a ┆          ┆           ┆           ┆   ┆           ┆ 6cb82065a ┆           ┆           │
# │ 93d…      ┆          ┆           ┆           ┆   ┆           ┆ 93d…      ┆           ┆           │
# │ 012baccc1 ┆ 2.441048 ┆ -0.022754 ┆ 307.86007 ┆ … ┆ false     ┆ 012baccc1 ┆ 220       ┆ 1         │
# │ 45d400c89 ┆          ┆           ┆ 7         ┆   ┆           ┆ 45d400c89 ┆           ┆           │
# │ 6cb82065a ┆          ┆           ┆           ┆   ┆           ┆ 6cb82065a ┆           ┆           │
# │ 93d…      ┆          ┆           ┆           ┆   ┆           ┆ 93d…      ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
tr_image_feat_df, ts_image_feat_df = utils.read_image_feature_type2_csv(
    TR_IMAGE_FEATURE_TYPE2_CSV,
    TS_IMAGE_FEATURE_TYPE2_CSV,
    n_patch=16,
    n_components=16,
    prefix="type2_",
)

tr_df = tr_df.join(tr_image_feat_df, on="ID")
ts_df = ts_df.join(ts_image_feat_df, on="ID")

del tr_image_feat_df, ts_image_feat_df
gc.collect()

tr_df.head(2)
# Out:
# shape: (2, 801)
# ┌───────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ ID        ┆ vEgo      ┆ aEgo     ┆ steeringA ┆ … ┆ type2_ima ┆ type2_ima ┆ type2_ima ┆ type2_ima │
# │ ---       ┆ ---       ┆ ---      ┆ ngleDeg   ┆   ┆ ge_feat_p ┆ ge_feat_p ┆ ge_feat_p ┆ ge_feat_p │
# │ str       ┆ f64       ┆ f64      ┆ ---       ┆   ┆ atch_15_p ┆ atch_15_p ┆ atch_15_p ┆ atch_15_p │
# │           ┆           ┆          ┆ f64       ┆   ┆ ca_…      ┆ ca_…      ┆ ca_…      ┆ ca_…      │
# │           ┆           ┆          ┆           ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆           ┆          ┆           ┆   ┆ f32       ┆ f32       ┆ f32       ┆ f32       │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 00066be8e ┆ 5.701526  ┆ 1.538456 ┆ -2.165777 ┆ … ┆ 1.2968    ┆ -2.511726 ┆ -2.452925 ┆ -2.568694 │
# │ 20318869c ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 38c66be46 ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 663…      ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 00066be8e ┆ 11.176292 ┆ 0.279881 ┆ -11.62569 ┆ … ┆ 4.889874  ┆ 6.756308  ┆ 2.842822  ┆ 2.864973  │
# │ 20318869c ┆           ┆          ┆ 7         ┆   ┆           ┆           ┆           ┆           │
# │ 38c66be46 ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 663…      ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# └───────────┴───────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
def reduce_base_pred(
    df: pl.DataFrame, base_pred_df: pl.DataFrame, has_target: bool
) -> pl.DataFrame:
    """
    基礎推定値のdfをconcatし、元のdfのtarget列から除去したdfを返す

    Args:
        df (pl.DataFrame): target列を持つDataFrame
        base_pred_df (pl.DataFrame): 基礎推定値のDataFrame
        has_target (bool): target列を持つかどうか
    """
    target_cols = TARGET_COLS
    base_pred_cols = BASE_PRED_COLS
    df = pl.concat(
        [
            df,
            base_pred_df.select(TARGET_COLS).rename(
                {t: b for t, b in zip(target_cols, base_pred_cols)}
            ),
        ],
        how="horizontal",
    )

    if has_target:
        df = df.with_columns(
            [
                (pl.col(tg_col) - pl.col(base_pred_col)).alias(tg_col)
                for tg_col, base_pred_col in zip(target_cols, base_pred_cols)
            ]
        )
    return df


def add_base_pred_to_target(df: pl.DataFrame, target_cols: list[str]) -> pl.DataFrame:
    """
    target_colsの列に基礎推定量を足したDataFrameを返す

    Args:
        df (pl.DataFrame): target列を持つDataFrame
        target_cols (list[str]): 追加する基礎推定量の列名
    """
    df = df.with_columns(
        [
            (pl.col(tg_col) + pl.col(bp_col)).alias(tg_col)
            for tg_col, bp_col in zip(target_cols, BASE_PRED_COLS)
        ]
    )

    return df


if BASE_PRED_DIR is not None:
    # columns: "x_0", "y_0", "z_0", ..., "x_5", "y_5", "z_5"
    base_oof_pred_df = pl.read_csv(BASE_OOF_PRED_CSV)
    base_submission_df = pl.read_csv(BASE_SUBMISSION_CSV)

    # 基礎推定値を元のtarget列から引いた値を新たなtarget列とする
    tr_df = reduce_base_pred(tr_df, base_oof_pred_df, has_target=True)
    ts_df = reduce_base_pred(ts_df, base_submission_df, has_target=False)

    del base_oof_pred_df, base_submission_df
    gc.collect()

# %%
tr_depth_images = utils.load_npy_images(
    IMAGES_DIR,
    ids=tr_df.get_column("ID").to_list(),
    image_names=DEPTH_IMAGE_NAMES,
).astype(np.float32)
print(tr_depth_images.shape)
ts_depth_images = utils.load_npy_images(
    IMAGES_DIR,
    ids=ts_df.get_column("ID").to_list(),
    image_names=DEPTH_IMAGE_NAMES,
).astype(np.float32)
print(ts_depth_images.shape)
# Out:
# (43371, 3, 64, 128, 1)
# (1727, 3, 64, 128, 1)

# %%
tr_optical_flow_images = utils.load_npy_images(
    IMAGES_DIR,
    ids=tr_df.get_column("ID").to_list(),
    image_names=[OPTICAL_FLOW_IMAGE_NAME],
).astype(np.float32)
print(tr_optical_flow_images.shape)
ts_optical_flow_images = utils.load_npy_images(
    IMAGES_DIR,
    ids=ts_df.get_column("ID").to_list(),
    image_names=[OPTICAL_FLOW_IMAGE_NAME],
).astype(np.float32)
print(ts_optical_flow_images.shape)
# Out:
# (43371, 1, 64, 128, 4)
# (1727, 1, 64, 128, 4)

# %% [markdown]
# ## scene_dsec順に並び替える

# %%
tr_df = tr_df.sort(["scene_id", "scene_dsec"])
ts_df = ts_df.sort(["scene_id", "scene_dsec"])

tr_depth_images = tr_depth_images[tr_df.get_column("origin_idx").to_numpy()]
ts_depth_images = ts_depth_images[ts_df.get_column("origin_idx").to_numpy()]

tr_optical_flow_images = tr_optical_flow_images[
    tr_df.get_column("origin_idx").to_numpy()
]
ts_optical_flow_images = ts_optical_flow_images[
    ts_df.get_column("origin_idx").to_numpy()
]

# %% [markdown]
# ## Target

# %%
target = utils.CoordinateTarget(prefix="tg_")
target.fit(tr_df)

tg_df = target.transform(tr_df)
print(tg_df.columns)
print(tg_df.describe().glimpse())
tr_df = pl.concat([tr_df, tg_df], how="horizontal")

del tg_df
gc.collect()
# Out:
# ['tg_cood_x_0', 'tg_cood_y_0', 'tg_cood_z_0', 'tg_cood_x_1', 'tg_cood_y_1', 'tg_cood_z_1', 'tg_cood_x_2', 'tg_cood_y_2', 'tg_cood_z_2', 'tg_cood_x_3', 'tg_cood_y_3', 'tg_cood_z_3', 'tg_cood_x_4', 'tg_cood_y_4', 'tg_cood_z_4', 'tg_cood_x_5', 'tg_cood_y_5', 'tg_cood_z_5']
# Rows: 9
# Columns: 19
# $ statistic   <str> 'count', 'null_count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'
# $ tg_cood_x_0 <f64> 43371.0, 0.0, -0.0006715892176898854, 0.09753700583172945, -2.057005512707679, -0.040399420711143996, -0.000568865584570144, 0.04032857916132482, 1.197693475530765
# $ tg_cood_y_0 <f64> 43371.0, 0.0, -0.00043051178186256537, 0.061965987833959645, -2.5740922230432965, -0.022298936290583313, -0.0011371778367903962, 0.02090260048404809, 3.8222068163710263
# $ tg_cood_z_0 <f64> 43371.0, 0.0, -4.1921114744582373e-05, 0.0401841568252421, -1.004058364214115, -0.01861453878059976, 0.00036592425384850667, 0.017990800193160003, 1.4501810662508412
# $ tg_cood_x_1 <f64> 43371.0, 0.0, -0.0010784820030265154, 0.19798676752684932, -4.054618770052394, -0.08464756664628315, -0.000815395051711576, 0.08539300330414434, 1.9465416434092715
print(ft_df.columns)
print(ft_df.describe().glimpse())
tr_df = pl.concat([tr_df, ft_df], how="horizontal")

ft_df = feature.transform(ts_df, ts_depth_images, ts_optical_flow_images)
print(ft_df.columns)
print(ft_df.describe().glimpse())
ts_df = pl.concat([ts_df, ft_df], how="horizontal")

del ft_df
gc.collect()
# Out:
# ['ft_vEgo', 'ft_aEgo', 'ft_steeringAngleDeg', 'ft_steeringTorque', 'ft_brake', 'ft_brakePressed', 'ft_gas', 'ft_gasPressed', 'ft_is_gearShifter_drive', 'ft_is_gearShifter_neutral', 'ft_is_gearShifter_park', 'ft_is_gearShifter_reverse', 'ft_leftBlinker', 'ft_rightBlinker', 'ft_prev_ft_vEgo', 'ft_prev_ft_aEgo', 'ft_prev_ft_steeringAngleDeg', 'ft_prev_ft_steeringTorque', 'ft_prev_ft_brake', 'ft_prev_ft_brakePressed', 'ft_prev_ft_gas', 'ft_prev_ft_gasPressed', 'ft_prev_ft_is_gearShifter_drive', 'ft_prev_ft_is_gearShifter_neutral', 'ft_prev_ft_is_gearShifter_park', 'ft_prev_ft_is_gearShifter_reverse', 'ft_prev_ft_leftBlinker', 'ft_prev_ft_rightBlinker', 'ft_next_ft_vEgo', 'ft_next_ft_aEgo', 'ft_next_ft_steeringAngleDeg', 'ft_next_ft_steeringTorque', 'ft_next_ft_brake', 'ft_next_ft_brakePressed', 'ft_next_ft_gas', 'ft_next_ft_gasPressed', 'ft_next_ft_is_gearShifter_drive', 'ft_next_ft_is_gearShifter_neutral', 'ft_next_ft_is_gearShifter_park', 'ft_next_ft_is_gearShifter_reverse', 'ft_next_ft_leftBlinker', 'ft_next_ft_rightBlinker', 'ft_prev_diff_ft_vEgo', 'ft_prev_diff_ft_aEgo', 'ft_prev_diff_ft_steeringAngleDeg', 'ft_prev_diff_ft_steeringTorque', 'ft_prev_diff_ft_brake', 'ft_prev_diff_ft_brakePressed', 'ft_prev_diff_ft_gas', 'ft_prev_diff_ft_gasPressed', 'ft_prev_diff_ft_is_gearShifter_drive', 'ft_prev_diff_ft_is_gearShifter_neutral', 'ft_prev_diff_ft_is_gearShifter_park', 'ft_prev_diff_ft_is_gearShifter_reverse', 'ft_prev_diff_ft_leftBlinker', 'ft_prev_diff_ft_rightBlinker', 'ft_next_diff_ft_vEgo', 'ft_next_diff_ft_aEgo', 'ft_next_diff_ft_steeringAngleDeg', 'ft_next_diff_ft_steeringTorque', 'ft_next_diff_ft_brake', 'ft_next_diff_ft_brakePressed', 'ft_next_diff_ft_gas', 'ft_next_diff_ft_gasPressed', 'ft_next_diff_ft_is_gearShifter_drive', 'ft_next_diff_ft_is_gearShifter_neutral', 'ft_next_diff_ft_is_gearShifter_park', 'ft_next_diff_ft_is_gearShifter_reverse', 'ft_next_diff_ft_leftBlinker', 'ft_next_diff_ft_rightBlinker', 'ft_depth_patch_mean_p0-c0', 'ft_depth_patch_mean_p1-c0', 'ft_depth_patch_mean_p2-c0', 'ft_depth_patch_mean_p3-c0', 'ft_depth_patch_mean_p4-c0', 'ft_depth_patch_mean_p5-c0', 'ft_depth_patch_mean_p6-c0', 'ft_depth_patch_mean_p7-c0', 'ft_depth_patch_mean_p8-c0', 'ft_depth_patch_mean_p9-c0', 'ft_depth_patch_mean_p10-c0', 'ft_depth_patch_mean_p11-c0', 'ft_depth_patch_mean_p12-c0', 'ft_depth_patch_mean_p13-c0', 'ft_depth_patch_mean_p14-c0', 'ft_depth_patch_mean_p15-c0', 'ft_depth_patch_std_p0-c0', 'ft_depth_patch_std_p1-c0', 'ft_depth_patch_std_p2-c0', 'ft_depth_patch_std_p3-c0', 'ft_depth_patch_std_p4-c0', 'ft_depth_patch_std_p5-c0', 'ft_depth_patch_std_p6-c0', 'ft_depth_patch_std_p7-c0', 'ft_depth_patch_std_p8-c0', 'ft_depth_patch_std_p9-c0', 'ft_depth_patch_std_p10-c0', 'ft_depth_patch_std_p11-c0', 'ft_depth_patch_std_p12-c0', 'ft_depth_patch_std_p13-c0', 'ft_depth_patch_std_p14-c0', 'ft_depth_patch_std_p15-c0', 'ft_depth_patch_max_p0-c0', 'ft_depth_patch_max_p1-c0', 'ft_depth_patch_max_p2-c0', 'ft_depth_patch_max_p3-c0', 'ft_depth_patch_max_p4-c0', 'ft_depth_patch_max_p5-c0', 'ft_depth_patch_max_p6-c0', 'ft_depth_patch_max_p7-c0', 'ft_depth_patch_max_p8-c0', 'ft_depth_patch_max_p9-c0', 'ft_depth_patch_max_p10-c0', 'ft_depth_patch_max_p11-c0', 'ft_depth_patch_max_p12-c0', 'ft_depth_patch_max_p13-c0', 'ft_depth_patch_max_p14-c0', 'ft_depth_patch_max_p15-c0', 'ft_depth_patch_min_p0-c0', 'ft_depth_patch_min_p1-c0', 'ft_depth_patch_min_p2-c0', 'ft_depth_patch_min_p3-c0', 'ft_depth_patch_min_p4-c0', 'ft_depth_patch_min_p5-c0', 'ft_depth_patch_min_p6-c0', 'ft_depth_patch_min_p7-c0', 'ft_depth_patch_min_p8-c0', 'ft_depth_patch_min_p9-c0', 'ft_depth_patch_min_p10-c0', 'ft_depth_patch_min_p11-c0', 'ft_depth_patch_min_p12-c0', 'ft_depth_patch_min_p13-c0', 'ft_depth_patch_min_p14-c0', 'ft_depth_patch_min_p15-c0', 'ft_depth_patch_mean_p0-c0_ch-diff', 'ft_depth_patch_mean_p0-c1_ch-diff', 'ft_depth_patch_mean_p1-c0_ch-diff', 'ft_depth_patch_mean_p1-c1_ch-diff', 'ft_depth_patch_mean_p2-c0_ch-diff', 'ft_depth_patch_mean_p2-c1_ch-diff ...
# Rows: 9
# Columns: 1305
# $ statistic                                          <str> 'count', 'null_count', 'mean', 'std', 'min', '25%', '50%', '75%', '
# $ ft_base_pred_y1                                    <f64> 1727.0, 0.0, -0.01055914217577181, 0.2936143124156375, -1.9341776565396767, -0.04067795976747292, 0.00263192946679753, 0.04064428640157884, 1.7293685751376822
# $ ft_base_pred_z1                                    <f64> 1727.0, 0.0, 0.0037635757634598877, 0.018690077297995124, -0.07295997757182565, -0.007241514282851191, 0.003541576945237629, 0.014615117392076674, 0.10487006777457955
# $ ft_base_pred_x2                                    <f64> 1727.0, 0.0, 13.707482969120655, 10.536298787429647, -0.7575274119659581, 3.9956305130729657, 13.17671466230413, 21.323613949434126, 39.28738824215241
# $ ft_base_pred_y2                                    <f64> 1727.0, 0.0, -0.025000129344198083, 0.5940252960054812, -3.7168753150255864, -0.08265858840178043, 0.004052254868964798, 0.080093787153365, 3.485229336422926
# $ ft_base_pred_z2                                    <f64> 1727.0, 0.0, 0.006016029847022978, 0.031604607466200564, -0.11438063121728813, -0.013593183244740743, 0.005481712848562666, 0.02486534304808775, 0.19197163665132108
# $ ft_base_pred_x3                                    <f64> 1727.0, 0.0, 18.401352788157688, 14.165579764497672, -0.757201550619936, 5.472948567188963, 17.647263609488395, 28.65483033383926, 52.65566758592579
# $ ft_base_pred_y3                                    <f64> 1727.0, 0.0, -0.04518378747841527, 0.9816171790473449, -5.777055594164373, -0.1461007040611904, 0.004198925135603049, 0.12922117427763044, 5.6337251075529835
# $ ft_base_pred_z3                                    <f64> 1727.0, 0.0, 0.007914262508910431, 0.04828533253643968, -0.1746049229235552, -0.021363976504135747, 0.0062110892687162675, 0.0350664923426358, 0.3018316532823671
# $ ft_base_pred_x4                                    <f64> 1727.0, 0.0, 23.073856420139066, 17.792303094841113, -0.7054653737076653, 6.7378232628462005, 21.963576898402106, 35.95193512355717, 65.95729072406368
# $ ft_base_pred_y4                                    <f64> 1727.0, 0.0, -0.0696210734611904, 1.448542584839206, -8.139939404596312, -0.21663284633310315, 0.007073132354697698, 0.1915141998673467, 8.116647958616522
# $ ft_base_pred_z4                                    <f64> 1727.0, 0.0, 0.00964856249029623, 0.0671034276870386, -0.261259696715708, -0.030162933143542632, 0.0064040472633620366, 0.04687556761710572, 0.4062040231326948
# $ ft_base_pred_x5                                    <f64> 1727.0, 0.0, 27.723750081650625, 21.41643243561374, -0.794395406537642, 8.08887145885543, 26.294840911074044, 43.25265182835462, 79.15800766917111
# $ ft_base_pred_y5                                    <f64> 1727.0, 0.0, -0.09825774589534654, 1.9915457707423696, -10.942000538163464, -0.3067286571145456, 0.009264875289066478, 0.2748309538902202, 10.789897905458277
# $ ft_base_pred_z5                                    <f64> 1727.0, 0.0, 0.010802369100427457, 0.09003945333031325, -0.42020776868901455, -0.04023091922019868, 0.006315595341084449, 0.05934574963762352, 0.5269272031422607
#
# None
# 0

# %%
del tr_depth_images, ts_depth_images
gc.collect()

del tr_optical_flow_images, ts_optical_flow_images
gc.collect()
# Out:
# 0

# %%
tr_use_cols = (
    ["ID", "scene_id", "scene_dsec", "origin_idx"]
    + TARGET_COLS
    + BASE_PRED_COLS
    + feature.columns
    + target.columns
)
ts_use_cols = (
    ["ID", "scene_id", "scene_dsec", "origin_idx"] + BASE_PRED_COLS + feature.columns
)
tr_df = tr_df.select(tr_use_cols)
ts_df = ts_df.select(ts_use_cols)

# %% [markdown]
# ## モデリング

# %%
N_SPLITS = 2

# %%
# model_params = {
#    "ridge": {
#        "alpha": 0.1,
#        "random_state": RANDOM_STATE,
#    }
# }
#
# fit_params = {}

model_params = {
    "gbdt": {
        "tree_method": "hist",
        "num_target": len(target.columns),
        "multi_strategy": "multi_output_tree",
        "objective": "reg:squarederror",
        "eval_metric": "rmse",
        "learning_rate": 0.001,
        "max_depth": 5,
        "max_leaves": 2 ** (4 - 1),
        "subsample": 0.5,
        "colsample_bytree": 1.0,
        "nthread": 8,
        "seed": RANDOM_STATE,
        # "device": "cuda",
    }
}

fit_params = {
    "gbdt": {
        "num_boost_round": 100000,
        "early_stopping_rounds": 500,
    }
}

# %%
models, oof_preds = utils.train(
    model_class=utils.XgbModel,
    # model_class=utils.LgbModel,
    # model_class=utils.RidgeModel,
    model_params=model_params,
    fit_params=fit_params,
    df=tr_df,
    target_cols=target.columns,
    feature_cols=feature.columns,
    group_col="scene_id",
    n_splits=N_SPLITS,
)
# Out:
# -----------------
# -----------------
# Training fold 0...
# train samples: 21685, valid samples: 21686
# [0]	train-rmse:0.40776	valid-rmse:0.40639
# [5000]	train-rmse:0.39501	valid-rmse:0.40528
# [10000]	train-rmse:0.38496	valid-rmse:0.40494
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 models, oof_preds = utils.train(
#       2     model_class=utils.XgbModel,
#       3     # model_class=utils.LgbModel,
#       4     # model_class=utils.RidgeModel,
#       5     model_params=model_params,
#       6     fit_params=fit_params,
#       7     df=tr_df,
#       8     target_cols=target.columns,
#       9     feature_cols=feature.columns,
#      10     group_col="scene_id",
#      11     n_splits=N_SPLITS,
#      12 )
#
# File ~/projects/atmacup/atmacup_18/experiments/main2/v00/v00_12_03/utils.py:1047, in train(model_class, model_params, fit_params, df, target_cols, feature_cols, group_col, n_splits)
#    1043 vl_df = df[vl_idx]
#    1045 model = model_class(model_params, fit_params)
# -> 1047 model.fit(
#    1048     tr_features=tr_df.select(feature_cols),
#    1049     tr_targets=tr_df.select(target_cols),
#    1050     vl_features=vl_df.select(feature_cols),
#    1051     vl_targets=vl_df.select(target_cols),
#    1052 )
#    1053 models.append(model)
#    1055 pred = model.predict(
#    1056     vl_df.select(feature_cols),
#    1057 )
#
# File ~/projects/atmacup/atmacup_18/experiments/main2/v00/v00_12_03/utils.py:951, in XgbModel.fit(self, tr_features, tr_targets, vl_features, vl_targets)
#     941 callbacks = [
#     942     xgb.callback.EarlyStopping(
#     943         rounds=early_stopping_rounds,
#    (...)
#     947     ),
#     948 ]
#     950 # モデルの学習
# --> 951 self.model = xgb.train(
#     952     self.model_params["gbdt"],
#     953     tr_dmatrix,
#     954     num_boost_round=num_boost_round,
#     955     evals=evals,
#     956     verbose_eval=num_boost_round // 20,
#     957     callbacks=callbacks,
#     958 )
#     960 return self
#
# File ~/projects/atmacup/atmacup_18/venv/lib/python3.10/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~/projects/atmacup/atmacup_18/venv/lib/python3.10/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/projects/atmacup/atmacup_18/venv/lib/python3.10/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# utils.plot_lgb_importance(
#    sum([model.models for model in models], []), models[0].feature_names
# )

# %%
oof_preds = oof_preds.select(pl.all().name.prefix("pred_"))
pred_cols = oof_preds.columns

tr_df = pl.concat([tr_df, oof_preds], how="horizontal")
tr_df

# %% [markdown]
# ## 評価

# %%
def calc_score(df: pl.DataFrame, pred_cols: list[str]):
    tg_cols = TARGET_COLS

    tg = df.select(tg_cols).to_numpy()
    pred = df.select(pred_cols).to_numpy()

    scores = np.abs(tg - pred).mean(axis=0)
    scores = {f"score_{col}": float(score) for col, score in zip(pred_cols, scores)}
    scores["avg"] = float(np.abs(tg - pred).mean())
    return scores


scores = calc_score(tr_df, pred_cols)
scores

# %%
utils.plot_calibration_curve(tr_df, pred_cols, n_bins=40)

# %%
if BASE_PRED_DIR is not None:
    # 差し引いていた基礎推定値を足して元のtarget, pred列に戻す
    tr_df = add_base_pred_to_target(tr_df, TARGET_COLS)
    tr_df = add_base_pred_to_target(tr_df, pred_cols)

# %%
if BASE_PRED_DIR is not None:
    scores = calc_score(tr_df, pred_cols)
    display(scores)

# %%
if BASE_PRED_DIR is not None:
    utils.plot_calibration_curve(tr_df, pred_cols, n_bins=40)

# %% [markdown]
# ## oofを保存

# %%
def create_submission_csv(preds: pl.DataFrame, filename: str = "submission.csv"):
    submission_cols = TARGET_COLS

    # validate preds columns
    if len(preds.columns) != len(submission_cols):
        raise ValueError(
            f"preds columns must be {len(submission_cols)}, but got {len(preds.columns)}"
        )

    preds.columns = submission_cols
    preds.write_csv(filename)
    print(f"Submission file is created: {filename}")


# 元の順番に戻して保存
create_submission_csv(tr_df.sort("origin_idx").select(pred_cols), "oof_preds.csv")

# %% [markdown]
# ## Submission

# %%
preds = utils.predict(
    models,
    ts_df,
    feature.columns,
    pred_cols=pred_cols,
)
pred_cols = preds.columns
ts_df = pl.concat([ts_df, preds], how="horizontal")

preds

# %%
if BASE_PRED_DIR is not None:
    # 差し引いていた基礎推定値を足して元のtarget, pred列に戻す
    ts_df = add_base_pred_to_target(ts_df, pred_cols)
    display(ts_df)

# %%
# 元の順番に戻す
ts_df = ts_df.sort("origin_idx")

# %%
create_submission_csv(ts_df.select(pred_cols), "submission.csv")
